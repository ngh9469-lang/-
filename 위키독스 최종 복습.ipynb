# %%
#Step 0. 필요한 모듈과 라이브러리를 로딩합니다.
import sys # 시스템
import os  # 시스템

import pandas as pd  # 판다스 : 데이터분석 라이브러리
import numpy as np   # 넘파이 : 숫자, 행렬 데이터 라이브러리

import chromedriver_autoinstaller
import selenium
from selenium.webdriver.common.by import By
from selenium import webdriver   # 웹 브라우저 자동화
import time    # 서버와 통신할 때 중간중간 시간 지연. 보통은 1초
from tqdm import tqdm   # for문 돌릴 때 진행상황을 %게이지로 알려준다.

# 워닝 무시
import warnings
warnings.filterwarnings('ignore')

# %%
# 크롬 브라우저 (위키독스) 띄우기
chromedriver_autoinstaller.install(cwd=True)
driver = webdriver.Chrome()   # driver : 크롬 브라우저
# driver : 크롬 브라우저
driver.get('https://wikidocs.net/')
time.sleep(2)    # 2초간 정지

# %%
# 첫번째 책 제목 추출
selector = ".book-subject"
elements = driver.find_elements(By.CSS_SELECTOR, selector)
elements[0].text
# Out:
# '점프 투 파이썬'

# %%
title_list = []

for title in elements:
    title_list.append(title.text)
print(len(title_list))
title_list
# Out:
# 20
# ['점프 투 파이썬',
#  '딥 러닝을 이용한 자연어 처리 입문',
#  '딥 러닝 파이토치 교과서 - 입문부터 LLM 파인튜닝까지',
#  '파이썬으로 배우는 알고리즘 트레이딩 (개정판-2쇄)',
#  '점프 투 자바',
#  '<랭체인LangChain 노트> - LangChain 한국어 튜토리얼🇰🇷',
#  '[ 문과생도 할 수 있는 ] 파이썬 업무 자동화 일잘러 되기 + 챗GPT',
#  '주식 시장을 이기는 마법의 자동매매',
#  '왕초보를 위한 Python: 쉽게 풀어 쓴 기초 문법과 실습',
#  '초보자를 위한 파이썬 300제',
#  'PyQt5 Tutorial - 파이썬으로 만드는 나만의 GUI 프로그램',
#  '사장님 몰래 하는 파이썬 업무자동화(부제 : 들키면 일 많아짐)',
#  '[Python 완전정복 시리즈] 2편 : Pandas DataFrame 완전정복',
#  '점프 투 장고',
#  '파이썬을 이용한 비트코인 자동매매 (개정판)',
#  '위키독스',
#  'C++ 이야기(A Story of C++)',
#  'IT 기술 노트',
#  'Must Learning with R (개정판)',
#  '라즈베리 파이 문서(2021.7 이전)']

# %%
elements[0].get_attribute('href')
# Out:
# 'https://wikidocs.net/book/1'

# %%
url_list = []

for url in elements:
    url_list.append(url.get_attribute('href'))
print(len(url_list))
url_list
# Out:
# 20
# ['https://wikidocs.net/book/1',
#  'https://wikidocs.net/book/2155',
#  'https://wikidocs.net/book/2788',
#  'https://wikidocs.net/book/110',
#  'https://wikidocs.net/book/31',
#  'https://wikidocs.net/book/14314',
#  'https://wikidocs.net/book/8581',
#  'https://wikidocs.net/book/1050',
#  'https://wikidocs.net/book/2',
#  'https://wikidocs.net/book/922',
#  'https://wikidocs.net/book/2165',
#  'https://wikidocs.net/book/6353',
#  'https://wikidocs.net/book/7188',
#  'https://wikidocs.net/book/4223',
#  'https://wikidocs.net/book/1665',
#  'https://wikidocs.net/book/20',
#  'https://wikidocs.net/book/2380',
#  'https://wikidocs.net/book/2184',
#  'https://wikidocs.net/book/4315',
#  'https://wikidocs.net/book/483']

# %%
df= pd.DataFrame({"title": title_list, "url": url_list})
df
# Out:
#                                            title  \
# 0                                       점프 투 파이썬
# 1                            딥 러닝을 이용한 자연어 처리 입문
# 2                딥 러닝 파이토치 교과서 - 입문부터 LLM 파인튜닝까지
# 3                   파이썬으로 배우는 알고리즘 트레이딩 (개정판-2쇄)
# 4                                        점프 투 자바
# 5       <랭체인LangChain 노트> - LangChain 한국어 튜토리얼🇰🇷
# 6       [ 문과생도 할 수 있는 ] 파이썬 업무 자동화 일잘러 되기 + 챗GPT
# 7                            주식 시장을 이기는 마법의 자동매매
# 8              왕초보를 위한 Python: 쉽게 풀어 쓴 기초 문법과 실습
# 9                               초보자를 위한 파이썬 300제
# 10       PyQt5 Tutorial - 파이썬으로 만드는 나만의 GUI 프로그램
# 11           사장님 몰래 하는 파이썬 업무자동화(부제 : 들키면 일 많아짐)
# 12  [Python 완전정복 시리즈] 2편 : Pandas DataFrame 완전정복
# 13                                       점프 투 장고
# 14                      파이썬을 이용한 비트코인 자동매매 (개정판)
# 15                                          위키독스
# 16                       C++ 이야기(A Story of C++)
# 17                                      IT 기술 노트
# 18                    Must Learning with R (개정판)
# 19                         라즈베리 파이 문서(2021.7 이전)
#
#                                 url
# 0       https://wikidocs.net/book/1
# 1    https://wikidocs.net/book/2155
# 2    https://wikidocs.net/book/2788
# 3     https://wikidocs.net/book/110
# 4      https://wikidocs.net/book/31
# 5   https://wikidocs.net/book/14314
# 6    https://wikidocs.net/book/8581
# 7    https://wikidocs.net/book/1050
# 8       https://wikidocs.net/book/2
# 9     https://wikidocs.net/book/922
# 10   https://wikidocs.net/book/2165
# 11   https://wikidocs.net/book/6353
# 12   https://wikidocs.net/book/7188
# 13   https://wikidocs.net/book/4223
# 14   https://wikidocs.net/book/1665
# 15     https://wikidocs.net/book/20
# 16   https://wikidocs.net/book/2380
# 17   https://wikidocs.net/book/2184
# 18   https://wikidocs.net/book/4315
# 19    https://wikidocs.net/book/483

# %%
df.to_csv('title2_url2.csv', encoding = 'utf-8-sig' ,index= False)

# %%
df = pd.read_csv('title2_url2.csv')
df.head(3)
# Out:
#                              title                             url
# 0                         점프 투 파이썬     https://wikidocs.net/book/1
# 1              딥 러닝을 이용한 자연어 처리 입문  https://wikidocs.net/book/2155
# 2  딥 러닝 파이토치 교과서 - 입문부터 LLM 파인튜닝까지  https://wikidocs.net/book/2788

# %%
chromedriver_autoinstaller.install(cwd=True)
driver = webdriver.Chrome()   # driver : 크롬 브라우저
# driver : 크롬 브라우저

# 첫번째 책 url 접속
i = 0
url = df['url'][i] 
driver.get(url)    
time.sleep(2)

# %%
target_info= {}

# %%
#책 제목
selector = '#load_content > div.page-header-wrapper > h1 > span.page-subject-text'
title = driver.find_element(By.CSS_SELECTOR, selector).text
title
target_info['title'] = title

# %%
# 지은이 
selector = "#load_content > div.book-info.row.clearfix > div:nth-child(2) > div:nth-child(1) > a"
author = driver.find_element(By.CSS_SELECTOR, selector).text
author
target_info['author'] = author

# %%
# 판매가
selector = "#load_content > div.book-info.row.clearfix > div:nth-child(2) > div:nth-child(4)"
price = driver.find_element(By.CSS_SELECTOR, selector).text
target_info['price'] = price

# %%
# 책 소개글
selector = "#load_content > div.page-content > p"
elements = driver.find_elements(By.CSS_SELECTOR, selector)
#elements[0].text

overview_list = []   # 여러 문장을 담을 바구니

for element in elements:
    overview_list.append(element.text)
    print(element.text)
    
overview_str = '\n'.join(overview_list)
target_info['overview_str'] = overview_str
# Out:
# 이 책은 파이썬이란 언어를 처음 접해보는 독자들과 프로그래밍을 한 번도 해 본적이 없는 사람들을 대상으로 한다. 프로그래밍을 할 때 사용되는 전문적인 용어들을 알기 쉽게 풀어서 쓰려고 노력하였으며, 파이썬이란 언어의 개별적인 특성만을 강조하지 않고 프로그래밍 전반에 관한 사항을 파이썬이란 언어를 통해 알 수 있도록 알기 쉽게 설명하였다.
# 파이썬에 대한 기본적인 지식을 알고 있는 사람이라도 이 책은 파이썬 프로그래밍에 대한 흥미를 가질 수 있는 좋은 안내서가 될 것이다. 이 책의 목표는 독자가 파이썬을 통해 프로그래밍에 대한 전반적인 이해를 갖게하는 것이며, 또 파이썬이라는 도구를 이용하여 원하는 프로그램을 쉽고 재미있게 만들 수 있게 하는 것이다.
# 점프 투 파이썬 개정 2판이 종이책으로 출간되었습니다. (2023년 6월 15일)

# %%
target_info
# Out:
# {'title': '점프 투 파이썬',
#  'author': '박응용',
#  'price': 'e-book 판매가 : 8,000원 (구매하기)',
#  'overview_str': '이 책은 파이썬이란 언어를 처음 접해보는 독자들과 프로그래밍을 한 번도 해 본적이 없는 사람들을 대상으로 한다. 프로그래밍을 할 때 사용되는 전문적인 용어들을 알기 쉽게 풀어서 쓰려고 노력하였으며, 파이썬이란 언어의 개별적인 특성만을 강조하지 않고 프로그래밍 전반에 관한 사항을 파이썬이란 언어를 통해 알 수 있도록 알기 쉽게 설명하였다.\n파이썬에 대한 기본적인 지식을 알고 있는 사람이라도 이 책은 파이썬 프로그래밍에 대한 흥미를 가질 수 있는 좋은 안내서가 될 것이다. 이 책의 목표는 독자가 파이썬을 통해 프로그래밍에 대한 전반적인 이해를 갖게하는 것이며, 또 파이썬이라는 도구를 이용하여 원하는 프로그램을 쉽고 재미있게 만들 수 있게 하는 것이다.\n점프 투 파이썬 개정 2판이 종이책으로 출간되었습니다. (2023년 6월 15일)'}

# %%
chromedriver_autoinstaller.install(cwd=True)

total_dict = {}

for i in range(0,10):
    try:
        driver = webdriver.Chrome()
        url = df['url'][i] 
        driver.get(url)    
        time.sleep(2)

        target_info = {}

        #책 제목
        selector = '#load_content > div.page-header-wrapper > h1 > span.page-subject-text'
        title = driver.find_element(By.CSS_SELECTOR, selector).text
        title
        target_info['title'] = title
        
        # 지은이 
        selector = "#load_content > div.book-info.row.clearfix > div:nth-child(2) > div:nth-child(1) > a"
        author = driver.find_element(By.CSS_SELECTOR, selector).text
        author
        target_info['author'] = author
        
        # 판매가
        try:
            selector = "#load_content > div.book-info.row.clearfix > div:nth-child(2) > div:nth-child(4)"
            price = driver.find_element(By.CSS_SELECTOR, selector).text
        # 추천 문구면 0으로 처리
            if "추천" in price:
                price = 0    
        except:                 #제외라는 뜻
            price = 0    
        target_info['price'] = price

        # 추천수
        try:
            selector = ".btn.btn-default.btn-xs strong"
            up = driver.find_element(By.CSS_SELECTOR, selector).text

            # 콤마 제거 후 숫자로 변환
            up = int(up.replace(',', ''))

        except:
            up = 0

        target_info['up'] = up
        print(up)
        
        
        # 책 소개글
        selector = "#load_content > div.page-content > p"
        elements = driver.find_elements(By.CSS_SELECTOR, selector)
        #elements[0].text
        
        overview_list = []   # 여러 문장을 담을 바구니
        
        for element in elements:
            overview_list.append(element.text)
            print(element.text)
            
        overview_str = '\n'.join(overview_list)
        target_info['overview_str'] = overview_str
        
        

        #위에 까지 다 그냥 가져온거 만든 거 아래 부터 공식처럼 추가
        print(target_info)
        total_dict[i] = target_info
        print(i+1, f"번째 책 '{title}' 내용이 수집되었습니다", "\n")
   
        driver.close()

    except:
        print(i+1, f"번째 책 '{title}' 에서 에러가 발생")
        continue
# Out:
# 7676
# 이 책은 파이썬이란 언어를 처음 접해보는 독자들과 프로그래밍을 한 번도 해 본적이 없는 사람들을 대상으로 한다. 프로그래밍을 할 때 사용되는 전문적인 용어들을 알기 쉽게 풀어서 쓰려고 노력하였으며, 파이썬이란 언어의 개별적인 특성만을 강조하지 않고 프로그래밍 전반에 관한 사항을 파이썬이란 언어를 통해 알 수 있도록 알기 쉽게 설명하였다.
# 파이썬에 대한 기본적인 지식을 알고 있는 사람이라도 이 책은 파이썬 프로그래밍에 대한 흥미를 가질 수 있는 좋은 안내서가 될 것이다. 이 책의 목표는 독자가 파이썬을 통해 프로그래밍에 대한 전반적인 이해를 갖게하는 것이며, 또 파이썬이라는 도구를 이용하여 원하는 프로그램을 쉽고 재미있게 만들 수 있게 하는 것이다.
# 점프 투 파이썬 개정 2판이 종이책으로 출간되었습니다. (2023년 6월 15일)
# {'title': '점프 투 파이썬', 'author': '박응용', 'price': 'e-book 판매가 : 8,000원 (구매하기)', 'up': 7676, 'overview_str': '이 책은 파이썬이란 언어를 처음 접해보는 독자들과 프로그래밍을 한 번도 해 본적이 없는 사람들을 대상으로 한다. 프로그래밍을 할 때 사용되는 전문적인 용어들을 알기 쉽게 풀어서 쓰려고 노력하였으며, 파이썬이란 언어의 개별적인 특성만을 강조하지 않고 프로그래밍 전반에 관한 사항을 파이썬이란 언어를 통해 알 수 있도록 알기 쉽게 설명하였다.\n파이썬에 대한 기본적인 지식을 알고 있는 사람이라도 이 책은 파이썬 프로그래밍에 대한 흥미를 가질 수 있는 좋은 안내서가 될 것이다. 이 책의 목표는 독자가 파이썬을 통해 프로그래밍에 대한 전반적인 이해를 갖게하는 것이며, 또 파이썬이라는 도구를 이용하여 원하는 프로그램을 쉽고 재미있게 만들 수 있게 하는 것이다.\n점프 투 파이썬 개정 2판이 종이책으로 출간되었습니다. (2023년 6월 15일)'}
# 1 번째 책 '점프 투 파이썬' 내용이 수집되었습니다
#
# 6785
# 26년 1월 기준: 누적 조회수: 1,950만 돌파 베스트셀러
# 많은 분들의 피드백으로 수 년간 보완된 현업 연구원들이 작성한 딥 러닝 자연어 처리 교재 입문서입니다.
# Q) 입문자도 공부 가능한가요?
# A) 이 책은 애초 AI를 아예 처음 공부하는 입문자가 타겟입니다. 파이썬을 어느 정도 할 줄 아신다면 AI 공부를 할 수 있습니다.
# Q) 이 책은 혹시 무료로 공부 가능한가요?
# A) 거의 90% 이상의 내용을 현재 무료로 공개했습니다. 그러니 무료로 편하게 입문하시기 바랍니다.
# 단, LLM 파인 튜닝 등 일부심화 내용은 유료 E-book/전체 PDF 파일에서만 볼 수 있습니다.
# Q) 이 책의 파이토치 버전은 없나요?
# A) 존재합니다. 참고로 요즘 트렌드는 파이토치가 더 많이 사용되고 있습니다. 따라서 저자도 이 책과 목차가 거의 동일하지만 좀 더 트렌디한 파이토치 도서를 좀 더 권장드립니다.
# Q) 입문자들이 쉽게 질문하고 소통할 수 있는 공간은 없나요?
# A) 자연어 처리 입문자들을 위한 오픈 카톡방: https://open.kakao.com/o/gciNJmPg
# 댓글 또는 피드백(질문/지적) 또는 이메일 환영합니다.
# 각 내용에 대한 페이지마다 댓글 버튼 옆을 보면 피드백 버튼이 있습니다.
# 위키독스 회원가입이 번거로우시다면 피드백 버튼으로 의견주셔도 댓글로 답변드립니다.
# 감사합니다.
# {'title': '딥 러닝을 이용한 자연어 처리 입문', 'author': '브라이스 유', 'price': 'e-book 판매가 : 33,000원 (구매하기)', 'up': 6785, 'overview_str': '26년 1월 기준: 누적 조회수: 1,950만 돌파 베스트셀러\n많은 분들의 피드백으로 수 년간 보완된 현업 연구원들이 작성한 딥 러닝 자연어 처리 교재 입문서입니다.\nQ) 입문자도 공부 가능한가요?\nA) 이 책은 애초 AI를 아예 처음 공부하는 입문자가 타겟입니다. 파이썬을 어느 정도 할 줄 아신다면 AI 공부를 할 수 있습니다.\nQ) 이 책은 혹시 무료로 공부 가능한가요?\nA) 거의 90% 이상의 내용을 현재 무료로 공개했습니다. 그러니 무료로 편하게 입문하시기 바랍니다.\n단, LLM 파인 튜닝 등 일부심화 내용은 유료 E-book/전체 PDF 파일에서만 볼 수 있습니다.\nQ) 이 책의 파이토치 버전은 없나요?\nA) 존재합니다. 참고로 요즘 트렌드는 파이토치가 더 많이 사용되고 있습니다. 따라서 저자도 이 책과 목차가 거의 동일하지만 좀 더 트렌디한 파이토치 도서를 좀 더 권장드립니다.\nQ) 입문자들이 쉽게 질문하고 소통할 수 있는 공간은 없나요?\nA) 자연어 처리 입문자들을 위한 오픈 카톡방: https://open.kakao.com/o/gciNJmPg\n댓글 또는 피드백(질문/지적) 또는 이메일 환영합니다.\n각 내용에 대한 페이지마다 댓글 버튼 옆을 보면 피드백 버튼이 있습니다.\n위키독스 회원가입이 번거로우시다면 피드백 버튼으로 의견주셔도 댓글로 답변드립니다.\n감사합니다.'}
# 2 번째 책 '딥 러닝을 이용한 자연어 처리 입문' 내용이 수집되었습니다
#
# 5354
# 26년 1월 기준: 누적 조회수: 490만 돌파 베스트셀러
# 딥 러닝 프레임워크 PyTorch와 허깅페이스의 Transformers를 사용하여 딥 러닝과 LLM에 입문하는 것을 목표로 합니다.
# AI의 완전 쌩 입문자들을 위해 만들어졌으며 인공지능은 몰라도 되며 파이썬은 조금 할 줄 알아야 합니다.
# 이 책은 파이토치 기초부터 언어 모델 파인 튜닝 실습까지 다룹니다.
# 90%의 내용을 무료로 공개하여 무료 내용만으로도 딥 러닝을 중급자 수준까지 공부할 수 있습니다.
# 단, LLM 파인튜닝 실습과 같은 심화 내용은 유료 E-book/전체 PDF 파일 에서만 확인할 수 있습니다.
# 이 책은 약 1,200 페이지 분량을 가지고 있습니다.
# 깃허브 주소: https://github.com/ukairia777/pytorch-nlp-tutorial
# Q) AI 아예 모르는 입문자인데 이 책으로 공부할 수 있을까요?
# A) AI를 아예 모르는 입문자도 공부 가능한 입문서입니다.
# Q) LLM을 공부하고 싶은데 이 책에서 다루나요?
# A) RAG 파트는 공개되어져 있습니다. LLM 파인튜닝과 멀티모달 VLM 파인튜닝 파트는 유료 E-book 구매 시 볼 수 있습니다.
# Q) LLM만 집중적으로 공부하고 싶은데 저자 직강의 강의는 없나요?
# A) 공동 저자 안상준님이 강남에서 매주 현장에서 질답을 받으며 진행되는 실시간으로 LLM 파인 튜닝과 나만의 에이전트 구축을 다루는 입문용 오프라인 강의도 존재합니다.
# 공부 관련해서 궁금한 점이 있으시면 아래 카톡방에 와서 질문해주셔도 좋습니다 :)
# 인공 지능 입문자들을 위한 오픈 카톡방: https://open.kakao.com/o/gciNJmPg
# 감사합니다.
# {'title': '딥 러닝 파이토치 교과서 - 입문부터 LLM 파인튜닝까지', 'author': '브라이스 유', 'price': 'e-book 판매가 : 33,000원 (구매하기)', 'up': 5354, 'overview_str': '26년 1월 기준: 누적 조회수: 490만 돌파 베스트셀러\n딥 러닝 프레임워크 PyTorch와 허깅페이스의 Transformers를 사용하여 딥 러닝과 LLM에 입문하는 것을 목표로 합니다.\nAI의 완전 쌩 입문자들을 위해 만들어졌으며 인공지능은 몰라도 되며 파이썬은 조금 할 줄 알아야 합니다.\n이 책은 파이토치 기초부터 언어 모델 파인 튜닝 실습까지 다룹니다.\n90%의 내용을 무료로 공개하여 무료 내용만으로도 딥 러닝을 중급자 수준까지 공부할 수 있습니다.\n단, LLM 파인튜닝 실습과 같은 심화 내용은 유료 E-book/전체 PDF 파일 에서만 확인할 수 있습니다.\n이 책은 약 1,200 페이지 분량을 가지고 있습니다.\n깃허브 주소: https://github.com/ukairia777/pytorch-nlp-tutorial\nQ) AI 아예 모르는 입문자인데 이 책으로 공부할 수 있을까요?\nA) AI를 아예 모르는 입문자도 공부 가능한 입문서입니다.\nQ) LLM을 공부하고 싶은데 이 책에서 다루나요?\nA) RAG 파트는 공개되어져 있습니다. LLM 파인튜닝과 멀티모달 VLM 파인튜닝 파트는 유료 E-book 구매 시 볼 수 있습니다.\nQ) LLM만 집중적으로 공부하고 싶은데 저자 직강의 강의는 없나요?\nA) 공동 저자 안상준님이 강남에서 매주 현장에서 질답을 받으며 진행되는 실시간으로 LLM 파인 튜닝과 나만의 에이전트 구축을 다루는 입문용 오프라인 강의도 존재합니다.\n공부 관련해서 궁금한 점이 있으시면 아래 카톡방에 와서 질문해주셔도 좋습니다 :)\n인공 지능 입문자들을 위한 오픈 카톡방: https://open.kakao.com/o/gciNJmPg\n감사합니다.'}
# 3 번째 책 '딥 러닝 파이토치 교과서 - 입문부터 LLM 파인튜닝까지' 내용이 수집되었습니다
#
# 4794
# 파이스탁 YouTube
# 리디북스 Ebook 구매 바로가기
# {'title': '파이썬으로 배우는 알고리즘 트레이딩 (개정판-2쇄)', 'author': '조대표', 'price': 0, 'up': 4794, 'overview_str': '파이스탁 YouTube\n리디북스 Ebook 구매 바로가기'}
# 4 번째 책 '파이썬으로 배우는 알고리즘 트레이딩 (개정판-2쇄)' 내용이 수집되었습니다
#
# 4656
# 이 책은 프로그래머를 꿈꾸며 자바 입문서를 찾는 사람들을 위한 책이다. 이 책은 자바의 문법을 하나하나 자세히 알기 보단 어렵게 느껴지는 자바를 쉽고 재미있게 이해하는 것을 목표로 삼고 있다. 예를 들어 인터페이스와 같은 개념에 대한 정의보다는 어디에, 어떻게 쓰이는지, 왜 필요한지 등에 초점을 맞춰 설명한다. 이 책을 통해 여러분은 직접 자바 코딩을 실습하며 프로그래밍 원리는 물론 실무에서 쓰이는 자바 기능들을 함께 익힐 수 있다.
# 이 책과 함께 여러분의 프로그래밍 여정이 더욱 빛나길 바란다!
# {'title': '점프 투 자바', 'author': '박응용', 'price': 'e-book 판매가 : 8,000원 (구매하기)', 'up': 4656, 'overview_str': '이 책은 프로그래머를 꿈꾸며 자바 입문서를 찾는 사람들을 위한 책이다. 이 책은 자바의 문법을 하나하나 자세히 알기 보단 어렵게 느껴지는 자바를 쉽고 재미있게 이해하는 것을 목표로 삼고 있다. 예를 들어 인터페이스와 같은 개념에 대한 정의보다는 어디에, 어떻게 쓰이는지, 왜 필요한지 등에 초점을 맞춰 설명한다. 이 책을 통해 여러분은 직접 자바 코딩을 실습하며 프로그래밍 원리는 물론 실무에서 쓰이는 자바 기능들을 함께 익힐 수 있다.\n이 책과 함께 여러분의 프로그래밍 여정이 더욱 빛나길 바란다!'}
# 5 번째 책 '점프 투 자바' 내용이 수집되었습니다
#
# 3697
# 추천은 공유할 수 있는 무료 전자책을 집필하는데 정말 큰 힘이 됩니다. "추천" 한 번씩만 부탁 드리겠습니다🙏🙏
# ✅ 랭체인 한국어 튜토리얼 강의
# 패스트캠퍼스 - RAG 비법노트
# ✅ 랭체인 한국어 튜토리얼 코드저장소(GitHub) 📘🖥️
# https://github.com/teddylee777/langchain-kr
# ✅ 유튜브 "테디노트" 🎥📚
# https://www.youtube.com/c/@teddynote
# ✅ 데이터 분석 블로그 https://teddylee777.github.io
# ✅ 문의 teddylee777@gmail.com
# 인용 및 출처 표기
# 상업적 사용에 대한 사전 협의
# {'title': '<랭체인LangChain 노트> - LangChain 한국어 튜토리얼🇰🇷', 'author': '테디노트', 'price': 0, 'up': 3697, 'overview_str': '추천은 공유할 수 있는 무료 전자책을 집필하는데 정말 큰 힘이 됩니다. "추천" 한 번씩만 부탁 드리겠습니다🙏🙏\n✅ 랭체인 한국어 튜토리얼 강의\n패스트캠퍼스 - RAG 비법노트\n✅ 랭체인 한국어 튜토리얼 코드저장소(GitHub) 📘🖥️\nhttps://github.com/teddylee777/langchain-kr\n✅ 유튜브 "테디노트" 🎥📚\nhttps://www.youtube.com/c/@teddynote\n✅ 데이터 분석 블로그 https://teddylee777.github.io\n✅ 문의 teddylee777@gmail.com\n인용 및 출처 표기\n상업적 사용에 대한 사전 협의'}
# 6 번째 책 '<랭체인LangChain 노트> - LangChain 한국어 튜토리얼🇰🇷' 내용이 수집되었습니다
#
# 1895
# "파이썬 업무 자동화 일잘러 되기 + 챗GPT"는 실무 경험을 토대로, 파이썬의 여러 기능과 생성AI를 활용하여 일상의 업무를 효율적으로 자동화할 수 있는 방법들을 소개합니다.
# 이 책은 워드 파일 기준 약 600페이지 분량을 가지고 있습니다. (24-07-05 기준)
# 저자는 본인의 실무 경험을 바탕으로, 파이썬과 생성AI를 활용하여 업무의 복잡성을 줄이고, 생산성을 높이는 다양한 방법들을 상세하게 소개합니다. 책에는 엑셀 데이터 처리부터 웹 스크레이핑까지, 다양한 실습 예제가 포함되어 있어 실제 업무에 즉시 적용할 수 있습니다.
# 특히, 이 책은 파이썬과 생성AI를 처음 접하는 초보자를 대상으로 하고 있어, 코드를 하나하나 이해하기 쉽게 설명합니다. 초보자들은 파이썬에 대해 자세히 알지 못하기 때문에 어떤 코드를 봤을 때 하나하나가 무엇을 의미하고 가리키는지 알 수 없어 더 어렵게 느껴집니다. 그렇다고 너무 복잡하니 일단 그냥 따라하라고 한다면 실습 코드로는 따라할 수 있겠지만 이 코드를 응용해서 자신의 업무를 자동화하려면 금새 또 막히고 맙니다. 따라서 이 책에서는 파이썬으로 어떤 작업을 하고자할 때 무슨 코드를 써야하는지를 소개하면서도, 해당 코드가 어떤 식으로 작동하는지, 왜 이러한 코드를 쓰는 것인지 최대한 이해하기 쉽게 풀어서 설명하려고 노력했습니다. 따라서 책의 설명을 잘 따라간다면 실제 각자의 업무를 자동화시키는 데도 활용할 수 있을 것입니다.
# 현대의 직장 생활에서 효율성은 선택이 아닌 필수입니다. 이 책을 통해, 파이썬과 생성AI에 조금 더 익숙해지고 실제 업무들을 자동화함으로써 일상 업무의 효율성을 한 단계 끌어올릴 수 있기를 바랍니다.
# 위키독스의 파이썬을 이용한 업무자동화 파트 일부를 발췌하여 챗GPT API 활용법과 실전 23가지 프로그램 만들기가 추가된버전으로 "파이썬 업무 자동화 일잘러 되기 + 챗GPT" 책이 출간 되었습니다. (출판사:골든래빗)
# 파이썬을 이용한 업무 자동화 부분도 위키독스에 비해 비교적 더 이해하기 쉽게 내용을 보완하였으며, 챗GPT API를 이용해 업무 자동화에 활용하는 법과 23가지 실전 예제를 더해 실제 업무에 적용하기 쉽도록 책을 제작하였습니다. 그리고 책이 내용을 바탕으로 유튜브에 무료 강의도 제공합니다. 따라서 출간된 책에도 많은 관심부탁드립니다.
# 챗GPT를 이용한 업무자동화 파트는 이후 위키독스에도 업데이트될 예정입니다.
# 책에서 사용하는 예제 파일과 코드는 깃허브에서 다운받을 수 있습니다.
# (생성AI를 이용한 업무자동화 강의) 직장인을 위한 GPTs 업무 자동화 - 사장님 몰래 일 편하게 하기!
# {'title': '[ 문과생도 할 수 있는 ] 파이썬 업무 자동화 일잘러 되기 + 챗GPT', 'author': '메이허', 'price': 0, 'up': 1895, 'overview_str': '"파이썬 업무 자동화 일잘러 되기 + 챗GPT"는 실무 경험을 토대로, 파이썬의 여러 기능과 생성AI를 활용하여 일상의 업무를 효율적으로 자동화할 수 있는 방법들을 소개합니다.\n이 책은 워드 파일 기준 약 600페이지 분량을 가지고 있습니다. (24-07-05 기준)\n저자는 본인의 실무 경험을 바탕으로, 파이썬과 생성AI를 활용하여 업무의 복잡성을 줄이고, 생산성을 높이는 다양한 방법들을 상세하게 소개합니다. 책에는 엑셀 데이터 처리부터 웹 스크레이핑까지, 다양한 실습 예제가 포함되어 있어 실제 업무에 즉시 적용할 수 있습니다.\n특히, 이 책은 파이썬과 생성AI를 처음 접하는 초보자를 대상으로 하고 있어, 코드를 하나하나 이해하기 쉽게 설명합니다. 초보자들은 파이썬에 대해 자세히 알지 못하기 때문에 어떤 코드를 봤을 때 하나하나가 무엇을 의미하고 가리키는지 알 수 없어 더 어렵게 느껴집니다. 그렇다고 너무 복잡하니 일단 그냥 따라하라고 한다면 실습 코드로는 따라할 수 있겠지만 이 코드를 응용해서 자신의 업무를 자동화하려면 금새 또 막히고 맙니다. 따라서 이 책에서는 파이썬으로 어떤 작업을 하고자할 때 무슨 코드를 써야하는지를 소개하면서도, 해당 코드가 어떤 식으로 작동하는지, 왜 이러한 코드를 쓰는 것인지 최대한 이해하기 쉽게 풀어서 설명하려고 노력했습니다. 따라서 책의 설명을 잘 따라간다면 실제 각자의 업무를 자동화시키는 데도 활용할 수 있을 것입니다.\n현대의 직장 생활에서 효율성은 선택이 아닌 필수입니다. 이 책을 통해, 파이썬과 생성AI에 조금 더 익숙해지고 실제 업무들을 자동화함으로써 일상 업무의 효율성을 한 단계 끌어올릴 수 있기를 바랍니다.\n위키독스의 파이썬을 이용한 업무자동화 파트 일부를 발췌하여 챗GPT API 활용법과 실전 23가지 프로그램 만들기가 추가된버전으로 "파이썬 업무 자동화 일잘러 되기 + 챗GPT" 책이 출간 되었습니다. (출판사:골든래빗)\n파이썬을 이용한 업무 자동화 부분도 위키독스에 비해 비교적 더 이해하기 쉽게 내용을 보완하였으며, 챗GPT API를 이용해 업무 자동화에 활용하는 법과 23가지 실전 예제를 더해 실제 업무에 적용하기 쉽도록 책을 제작하였습니다. 그리고 책이 내용을 바탕으로 유튜브에 무료 강의도 제공합니다. 따라서 출간된 책에도 많은 관심부탁드립니다.\n챗GPT를 이용한 업무자동화 파트는 이후 위키독스에도 업데이트될 예정입니다.\n책에서 사용하는 예제 파일과 코드는 깃허브에서 다운받을 수 있습니다.\n(생성AI를 이용한 업무자동화 강의) 직장인을 위한 GPTs 업무 자동화 - 사장님 몰래 일 편하게 하기!'}
# 7 번째 책 '[ 문과생도 할 수 있는 ] 파이썬 업무 자동화 일잘러 되기 + 챗GPT' 내용이 수집되었습니다
#
# 1317
# 100세 시대를 맞아 소액투자에 적합한 자동매매에 대한 종합 지식을 배우고 무료로 제공되는 자동매매 프로그램을 통해 실습과 연구를 하여 자신만의 수익모델을 보유하는 것을 최종 목표로 한다. 이를 통해 노후를 대비하고 일상에선 월급외의 부가수입을 꾸준히 창출한다.
# 적정 자본금으로 전업투자까지 가능한 주식(현물) 자동매매 프로그램의 실전 경험을 통한 노하우 공유와 안내를 통해 평생 수입을 보장하는 수익모델을 개발하는 마법의 세계로 여러분을 안내한다.
# ▶ 대한민국 천만 사용자가 자동매매 프로그램을 쉽게 사용하는 그날까지
# ▶ 번개트레이더 사용자 네이버 카페 [바로가기]
# ▶ 도서 출간 기념 이벤트 진행 중 [바로가기]
#
# {'title': '주식 시장을 이기는 마법의 자동매매', 'author': '엑슬론', 'price': 0, 'up': 1317, 'overview_str': '100세 시대를 맞아 소액투자에 적합한 자동매매에 대한 종합 지식을 배우고 무료로 제공되는 자동매매 프로그램을 통해 실습과 연구를 하여 자신만의 수익모델을 보유하는 것을 최종 목표로 한다. 이를 통해 노후를 대비하고 일상에선 월급외의 부가수입을 꾸준히 창출한다.\n적정 자본금으로 전업투자까지 가능한 주식(현물) 자동매매 프로그램의 실전 경험을 통한 노하우 공유와 안내를 통해 평생 수입을 보장하는 수익모델을 개발하는 마법의 세계로 여러분을 안내한다.\n▶ 대한민국 천만 사용자가 자동매매 프로그램을 쉽게 사용하는 그날까지\n▶ 번개트레이더 사용자 네이버 카페 [바로가기]\n▶ 도서 출간 기념 이벤트 진행 중 [바로가기]\n'}
# 8 번째 책 '주식 시장을 이기는 마법의 자동매매' 내용이 수집되었습니다
#
# 1153
# 프로그래밍을 한 번도 해본 적이 없는 분들을 위해, 파이썬을 통해 처음으로 프로그래밍을 시작하도록 도와드립니다.
# 0 머리말
# 1 파이썬 시작하기
# 2 제어구조
# 3 함수
# 4 데이터 타입
# 5 모듈
# 6 파일
# 7 객체지향
# 8 예외
# 9 테스팅과 성능
# 부록 A. 조금 어려운 문법
# 부록 B. 팁과 응용 예제
# ※ 심화 문제와 부록은 전자책에만 있습니다.
# {'title': '왕초보를 위한 Python: 쉽게 풀어 쓴 기초 문법과 실습', 'author': '전뇌해커', 'price': 'e-book 판매가 : 14,000원 (구매하기)', 'up': 1153, 'overview_str': '프로그래밍을 한 번도 해본 적이 없는 분들을 위해, 파이썬을 통해 처음으로 프로그래밍을 시작하도록 도와드립니다.\n0 머리말\n1 파이썬 시작하기\n2 제어구조\n3 함수\n4 데이터 타입\n5 모듈\n6 파일\n7 객체지향\n8 예외\n9 테스팅과 성능\n부록 A. 조금 어려운 문법\n부록 B. 팁과 응용 예제\n※ 심화 문제와 부록은 전자책에만 있습니다.'}
# 9 번째 책 '왕초보를 위한 Python: 쉽게 풀어 쓴 기초 문법과 실습' 내용이 수집되었습니다
#
# 761
# 파이썬 기초 문법을 배웠다고 해서 누구나 프로그래밍에 익숙해지는 것은 아닙니다. 프로그래밍에 익숙해지기까지 많은 문제를 풀어보고 익숙해지는 것이 필요합니다. 파이썬 300제는 파이썬 기초 문법과 관련된 문제들을 제공합니다. 파이썬 300제를 통해 지금까지 배운 기초 문법을 익혀보세요. 문제를 풀다가 막히는 부분은 각 문제 페이지 하단에 있는 유튜브 동영상을 참고하세요.
# {'title': '초보자를 위한 파이썬 300제', 'author': '조대표', 'price': 0, 'up': 761, 'overview_str': '파이썬 기초 문법을 배웠다고 해서 누구나 프로그래밍에 익숙해지는 것은 아닙니다. 프로그래밍에 익숙해지기까지 많은 문제를 풀어보고 익숙해지는 것이 필요합니다. 파이썬 300제는 파이썬 기초 문법과 관련된 문제들을 제공합니다. 파이썬 300제를 통해 지금까지 배운 기초 문법을 익혀보세요. 문제를 풀다가 막히는 부분은 각 문제 페이지 하단에 있는 유튜브 동영상을 참고하세요.'}
# 10 번째 책 '초보자를 위한 파이썬 300제' 내용이 수집되었습니다

# %%
df_final = pd.DataFrame.from_dict(total_dict, 'index')
df_final
# Out:
#                                       title  author  \
# 0                                  점프 투 파이썬     박응용
# 1                       딥 러닝을 이용한 자연어 처리 입문  브라이스 유
# 2           딥 러닝 파이토치 교과서 - 입문부터 LLM 파인튜닝까지  브라이스 유
# 3              파이썬으로 배우는 알고리즘 트레이딩 (개정판-2쇄)     조대표
# 4                                   점프 투 자바     박응용
# 5  <랭체인LangChain 노트> - LangChain 한국어 튜토리얼🇰🇷    테디노트
# 6  [ 문과생도 할 수 있는 ] 파이썬 업무 자동화 일잘러 되기 + 챗GPT     메이허
# 7                       주식 시장을 이기는 마법의 자동매매     엑슬론
# 8         왕초보를 위한 Python: 쉽게 풀어 쓴 기초 문법과 실습    전뇌해커
# 9                          초보자를 위한 파이썬 300제     조대표
#
#                          price    up  \
# 0   e-book 판매가 : 8,000원 (구매하기)  7676
# 1  e-book 판매가 : 33,000원 (구매하기)  6785
# 2  e-book 판매가 : 33,000원 (구매하기)  5354
# 3                            0  4794
# 4   e-book 판매가 : 8,000원 (구매하기)  4656
# 5                            0  3697
# 6                            0  1895
# 7                            0  1317
# 8  e-book 판매가 : 14,000원 (구매하기)  1153
# 9                            0   761
#
#                                         overview_str
# 0  이 책은 파이썬이란 언어를 처음 접해보는 독자들과 프로그래밍을 한 번도 해 본적이 ...
# 1  26년 1월 기준: 누적 조회수: 1,950만 돌파 베스트셀러\n많은 분들의 피드백...
# 2  26년 1월 기준: 누적 조회수: 490만 돌파 베스트셀러\n딥 러닝 프레임워크 P...
# 3                   파이스탁 YouTube\n리디북스 Ebook 구매 바로가기
# 4  이 책은 프로그래머를 꿈꾸며 자바 입문서를 찾는 사람들을 위한 책이다. 이 책은 자...
# 5  추천은 공유할 수 있는 무료 전자책을 집필하는데 정말 큰 힘이 됩니다. "추천" 한...
# 6  "파이썬 업무 자동화 일잘러 되기 + 챗GPT"는 실무 경험을 토대로, 파이썬의 여...
# 7  100세 시대를 맞아 소액투자에 적합한 자동매매에 대한 종합 지식을 배우고 무료로 ...
# 8  프로그래밍을 한 번도 해본 적이 없는 분들을 위해, 파이썬을 통해 처음으로 프로그래...
# 9  파이썬 기초 문법을 배웠다고 해서 누구나 프로그래밍에 익숙해지는 것은 아닙니다. 프...
